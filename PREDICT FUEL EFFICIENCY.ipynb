# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import tensorflow as tf
from tensorflow import keras
from keras import layers

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
print(df.shape)
df = df[df['horsepower'] != '?']
print(df.shape)
# Out:
# (398, 9)
# (392, 9)

# %%
df['horsepower'] = df['horsepower'].astype(int)
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# model year       13
# origin            3
# car name        301
# dtype: int64

# %%
plt.subplots(figsize=(15, 5))
for i, col in enumerate(['cylinders', 'origin']):
	plt.subplot(1, 2, i+1)
	x = df.groupby(col).mean()['mpg']
	x.plot.bar()
	plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df = df.select_dtypes(include=[np.number])

# %%
df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(8, 8))
sb.heatmap(df.corr() > 0.9,
		annot=True,
		cbar=False)
plt.show()

# %%
df.drop('displacement',
		axis=1,
		inplace=True)

# %%
from sklearn.model_selection import train_test_split
features = df.drop(['mpg', 'cylinders'], axis=1)
target = df['mpg'].values

X_train, X_val, Y_train, Y_val = train_test_split(features, target,
                                                    test_size=0.2,
                                                    random_state=22)
X_train.shape, X_val.shape
# Out:
# ((313, 5), (79, 5))

# %%
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_train, Y_train))
	.batch(32)
	.prefetch(AUTO)
)

val_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_val, Y_val))
	.batch(32)
	.prefetch(AUTO)
)

# %%
model = keras.Sequential([
	layers.Dense(256, activation='relu', input_shape=[6]),
	layers.BatchNormalization(),
	layers.Dense(256, activation='relu'),
	layers.Dropout(0.3),
	layers.BatchNormalization(),
	layers.Dense(1, activation='relu')
])

# %%
model.compile(
	loss='mae',
	optimizer='adam',
	metrics=['mape']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1792
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 69889 (273.00 KB)
# Trainable params: 68865 (269.00 KB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=(5,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 22ms/step - loss: -12694.9541 - accuracy: 0.0000e+00 - val_loss: -17814.3965 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 10/10 [==============================] - 0s 4ms/step - loss: -21802.8789 - accuracy: 0.0000e+00 - val_loss: -27012.9844 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 10/10 [==============================] - 0s 4ms/step - loss: -31679.9941 - accuracy: 0.0000e+00 - val_loss: -37692.9570 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 10/10 [==============================] - 0s 4ms/step - loss: -43155.7070 - accuracy: 0.0000e+00 - val_loss: -50172.2656 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 10/10 [==============================] - 0s 4ms/step - loss: -56647.0469 - accuracy: 0.0000e+00 - val_loss: -64933.5078 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 10/10 [==============================] - 0s 4ms/step - loss: -72658.7344 - accuracy: 0.0000e+00 - val_loss: -82499.7812 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 10/10 [==============================] - 0s 4ms/step - loss: -91727.0703 - accuracy: 0.0000e+00 - val_loss: -103416.9297 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 10/10 [==============================] - 0s 6ms/step - loss: -114409.3125 - accuracy: 0.0000e+00 - val_loss: -128251.5859 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: -141285.9375 - accuracy: 0.0000e+00 - val_loss: -157596.7188 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 10/10 [==============================] - 0s 5ms/step - loss: -172965.8594 - accuracy: 0.0000e+00 - val_loss: -192075.0625 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 10/10 [==============================] - 0s 4ms/step - loss: -210085.2344 - accuracy: 0.0000e+00 - val_loss: -232329.4375 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 10/10 [==============================] - 0s 4ms/step - loss: -253290.8438 - accuracy: 0.0000e+00 - val_loss: -279000.9688 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 10/10 [==============================] - 0s 4ms/step - loss: -303220.9688 - accuracy: 0.0000e+00 - val_loss: -332716.0312 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 10/10 [==============================] - 0s 4ms/step - loss: -360498.8438 - accuracy: 0.0000e+00 - val_loss: -394088.3438 - val_accuracy: 0.0000e+00
# Epoch 15/50
#
- val_accuracy: 0.0000e+00
# Epoch 37/50
# 10/10 [==============================] - 0s 6ms/step - loss: -5137085.5000 - accuracy: 0.0000e+00 - val_loss: -5344018.0000 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 10/10 [==============================] - 0s 4ms/step - loss: -5560787.5000 - accuracy: 0.0000e+00 - val_loss: -5785336.5000 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 10/10 [==============================] - 0s 4ms/step - loss: -6017375.5000 - accuracy: 0.0000e+00 - val_loss: -6255878.5000 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 10/10 [==============================] - 0s 4ms/step - loss: -6502468.0000 - accuracy: 0.0000e+00 - val_loss: -6754316.0000 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 10/10 [==============================] - 0s 4ms/step - loss: -7015582.0000 - accuracy: 0.0000e+00 - val_loss: -7280713.5000 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 10/10 [==============================] - 0s 4ms/step - loss: -7556921.5000 - accuracy: 0.0000e+00 - val_loss: -7835391.0000 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 10/10 [==============================] - 0s 4ms/step - loss: -8126852.5000 - accuracy: 0.0000e+00 - val_loss: -8418758.0000 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 10/10 [==============================] - 0s 4ms/step - loss: -8725807.0000 - accuracy: 0.0000e+00 - val_loss: -9031264.0000 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 10/10 [==============================] - 0s 4ms/step - loss: -9354252.0000 - accuracy: 0.0000e+00 - val_loss: -9673391.0000 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 10/10 [==============================] - 0s 4ms/step - loss: -10012679.0000 - accuracy: 0.0000e+00 - val_loss: -10345632.0000 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 10/10 [==============================] - 0s 4ms/step - loss: -10701585.0000 - accuracy: 0.0000e+00 - val_loss: -11048489.0000 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 10/10 [==============================] - 0s 4ms/step - loss: -11421481.0000 - accuracy: 0.0000e+00 - val_loss: -11782470.0000 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 10/10 [==============================] - 0s 4ms/step - loss: -12172874.0000 - accuracy: 0.0000e+00 - val_loss: -12548085.0000 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 10/10 [==============================] - 0s 4ms/step - loss: -12956281.0000 - accuracy: 0.0000e+00 - val_loss: -13345842.0000 - val_accuracy: 0.0000e+00

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#            loss  accuracy      val_loss  val_accuracy
# 0 -12694.954102       0.0 -17814.396484           0.0
# 1 -21802.878906       0.0 -27012.984375           0.0
# 2 -31679.994141       0.0 -37692.957031           0.0
# 3 -43155.707031       0.0 -50172.265625           0.0
# 4 -56647.046875       0.0 -64933.507812           0.0

# %%
 print(history_df.columns)
# Out:
# Index(['loss', 'accuracy', 'val_loss', 'val_accuracy'], dtype='object')

# %%
history_df.head()
# Out:
#            loss  accuracy      val_loss  val_accuracy
# 0 -12694.954102       0.0 -17814.396484           0.0
# 1 -21802.878906       0.0 -27012.984375           0.0
# 2 -31679.994141       0.0 -37692.957031           0.0
# 3 -43155.707031       0.0 -50172.265625           0.0
# 4 -56647.046875       0.0 -64933.507812           0.0

# %%
history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['accuracy', 'val_accuracy']].plot()
plt.show()
